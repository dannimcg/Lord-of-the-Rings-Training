# %%
from data_processing.generation import text_gen

# %%
text_gen()
# Out:
# usage: ipykernel_launcher [-h] --model_type MODEL_TYPE --model_name_or_path
#                           MODEL_NAME_OR_PATH [--prompt PROMPT]
#                           [--padding_text PADDING_TEXT] [--xlm_lang XLM_LANG]
#                           [--length LENGTH] [--num_samples NUM_SAMPLES]
#                           [--temperature TEMPERATURE]
#                           [--repetition_penalty REPETITION_PENALTY]
#                           [--top_k TOP_K] [--top_p TOP_P] [--no_cuda]
#                           [--seed SEED] [--stop_token STOP_TOKEN]
# ipykernel_launcher: error: the following arguments are required: --model_type, --model_name_or_path
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 300 --prompt "Aragon looked at the cloaked figure."
# Out:
#  He was no longer cloaked but in a brown woolen cloak; and the edge of his sword hung with the Elven-cloak above the belt.
#      'Away now!' cried Aragorn. 'Up into the glade! Follow me! It will be glad to hear the rumour that Boromir perished there.'
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 300 --temperature 0.5 --prompt "Aragon looked at the cloaked figure."
# Out:
#  He was clad in mail, and his helm was of silver, and his sword was of elven-scales. He was clad in mail and wore a helm of silver, and on his helm was a crown of gold.
#      'Aragorn son of Arathorn!' cried Legolas. 'The Lord of the Mark!'
#      'I am called Aragorn son of Arathorn,' said Aragorn. 'I am the heir of Isildur, the Steward of Gondor, and the Steward of the Mark of Rohan. I am Aragorn son of Arathorn, the Steward of the Mark of Rohan, and the Steward of the City of Gondor. I am the Steward of Gondor, and the Steward of the City of Gondor. I am the Steward of the City of Gondor, and the Steward of the City of Gondor. I am the Steward of the City of Gondor, and the Steward of the City of Gondor. I am the Steward of the City of Gondor, and the Steward of the City of Gondor. I am the Steward of the City of Gondor, and the Steward of the City of Gondor.'
#      'I am called Aragorn son of Arathorn,' said Gimli
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 300 --temperature 0.8 --prompt "Aragon looked at the cloaked figure."
# Out:
#  He was no longer cloaked but in a dark grey cloak. His face was troubled and grave, and he was gazing up at the sky, as if he was pondering some matter of great concern.
#      'Nay,' said Aragorn, 'if we had dared to speak thus openly in Lórien, it would have been a dishonour to our friend. For the matter is not yet closed. The Enemy has done much to strengthen the might of Mordor. It will be some days yet before we can hope to move him. But there is a hope in the hope that he has learned his lesson, and that he will take this Ring from the hands of the Enemy, and then you may come back to your own land.'
#       'Maybe, maybe,' said Gandalf. 'It is not so. I doubt it. But there is some hope in this. I do not doubt that you will come back to your own land. You are not far from the borders of the Shire, and you will find there many kindred of kindred in the land. If Gandalf comes, you will find that many still live and walk together in peace.'
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --temperature 0.8 --prompt "Aragon looked at the cloaked figure."
# Out:
#  He was no longer cloaked but in a dark grey cloak. His face was troubled and grave, and he was gazing up at the sky, as if he was pondering some matter of great concern.
#      'Nay,' said Aragorn, 'if we had dared to speak thus openly in Lórien, it would have been a dishonour to our friend. For the matter is not yet closed. The Enemy has done much to strengthen the might of Mordor. It will be some days yet before we can hope to move him. But there is a hope in the hope that he has learned his lesson, and that he will take this Ring from the hands of the Enemy, and then you may come back to your own land.'
#       'Maybe, maybe,' said Gandalf. 'It is not so. I doubt it. But there is some hope in this. I do not doubt that you will come back to your own land. You are not far from the borders of the Shire, and you will find there many kindred of kindred in the land. If Gandalf comes, you will find that many still live and walk together in peace.'
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --temperature 0.7 --prompt "Aragon looked at the cloaked figure."
# Out:
#  He was no longer cloaked but in a dark grey cloak. His face was grave and gravely concerned; but he was smiling.
#      'Hail, Master of the Tower!' he cried. 'Hail, Aragorn son of Arathorn! If you come to Minas Tirith, come to me! We must find a way to the Door, and so to the Great Gate. But there is no need to be afraid. I have many eyes on you. Will you come to me? Will you tell me what you have seen? For the Lady Éowyn is here.'
#      'I will come,' said Aragorn. 'But first, Éowyn, I must go.'
#       'Then Éowyn must stay here, and stay here, until we reach the Door,' she said. 'And if she does not come, I will come alone, to the Door, and maybe find her and bring her to me.'
#       'Then I will come,' said Aragorn. 'But first, I must go. And if I do not, then she will have no other choice but to stay here and wait for me. Therefore I will come with you.'
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --temperature 0.75 --prompt "Aragon looked at the cloaked figure."
# Out:
#  He was no longer cloaked but in a dark grey cloak. His face was grave and gravely concerned; but at the same time his eyes were looking at Aragorn.
#      'We have seen him,' said Aragorn. 'He is the heir of Elrond, and yet not of the House of Eorl. He is the only heir of the House of Eorl that has not passed into the House of Denethor. It is a dark hour.'
#      'It is a strange hour,' said Gandalf. 'What is the hour?'
#      'I do not know. It is dark and still,' answered Aragorn. 'It may be that I must come to the battle of the fields, and that I shall see tidings of your peril. The day before yesterday was grey, and there was no sign of battle. But I thought that the Eye of Mordor was now in the East and was looking eastward, away to the east, away from the Havens, towards the land of the Shadow. But how far is it? How far is it, I wonder.'
#      'It is not far,' said Gandalf. 'But in a day of fear, and in a dark hour of peril.'
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --temperature 0.78 --top_p 0.5 --prompt "Aragon looked at the cloaked figure."
# Out:
# ...
# 100%|██████████| 500/500 [00:33<00:00, 14.74it/s]
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --top_p 0.5 --prompt "Aragon looked at the cloaked figure."
# Out:
#  He was no longer cloaked, but was now standing upright, his arms stretched out, as if he was gazing at something far off.
#      'Hail, lord of the Mark!' he cried. 'Welcome to the City! I am Aragorn son of Arathorn, the King of the Mark. But you are no longer a king, but a man of many gifts. Your folk are in great need. You have ridden far, and you are weary. Farewell!'
#      'For I have not ridden far,' said Éomer. 'But you are a man of great wisdom, and a wise leader. Farewell!'
#       'Hail, Éomer!' said Aragorn. 'It is good to see you again!'
#       'May I come with you?' said Éowyn. 'May I come with you?'
#       'Yes, lady,' said Aragorn. 'I will come. But first I must go to the Council. I must speak with you.'
#       'I will come,' she said. 'And speak with you first. And you shall have a seat beside me, and I will sit beside you. And you shall have a cloak of mail, and a sword of the House of Eorl. I will be your guide.'
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --top_p 0.8 --prompt "Aragon looked at the cloaked figure."
# Out:
#  He was no longer cloaked but in a brownish cloak. His helm was thrown back, and on his helm was a small golden star, and on his breast was a small pearl of white glass. His feet were on the ground and there was no sign of feet or hands. He had a broad sword.
#      Aragorn knelt beside him, bending his hands upon his breast. 'It is not the mark of your race,' he said, 'that you have a sword.'
#      'It is,' said Legolas. 'Indeed the Men of the East are descended from Dwarves, descended from the heirs of the King of the Mountains. Some of our own kin used to dwell in the lands of Eregion; and they have long been friends with the Men of Rohan, as they are still with the Elves, for they go back and speak the Common Speech of Elves. But even in these days they still speak in their own tongue, which they call Númenor.'
#       'Númenor!' cried Aragorn. 'We see a sign in the Elf-cloak that some evil thing may have come here; but why now? What is this thing that we have seen, Legolas?'
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 1000 --top_p 0.85 --prompt "Aragon looked at the cloaked figure."
# Out:
#  He was no longer cloaked but in a brownish cloak. When he was seen Gandalf looked up, and when he saw Aragorn the Elf cried aloud in wonder.06/03/2021 09:31:38 - INFO - __main__ -   Namespace(model_type='gpt2', model_name_or_path='output', prompt='Aragon looked at the cloaked figure.', padding_text='', xlm_lang='', length=1000, num_samples=1, temperature=1.0, repetition_penalty=1.0, top_k=0, top_p=0.85, no_cuda=False, seed=42, stop_token=None, device=device(type='cuda'), n_gpu=1)
#
# ...
#  16%|█▌        | 155/1000 [00:05<00:41, 20.17it/s]
#
#      'Farewell!' cried Legolas. 'The new Moon is come out. Light and clear, yet yet marvellous. But this will do no good to the Elves. Their signs are evil. Great evil is coming upon them.'
#      'Then let us take all we can find,' said Gimli.
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --top_p 0.8 --prompt "Gandalf smiled."
# Out:
#  `Good-bye, Sam!' he said. `I have come to reward you for all your patience. Your trouble will be over soon. But for myself, I am going to talk with Boromir. I hope he will have a bit of good news.'
#      `Speak no more of Boromir!' said Sam. `Don't tell any secrets! Nothing's to be discovered until we speak face to face. I hope he'll be able to tell you about himself, before long, as you can see. And now, my dear hobbit, let me say a word to you. I shall see that you don't lose your Bag. I'll think of my birthday, and other presents, when you have had a bit of sleep. I shall be very glad indeed. But I shall stay here, if I can, until you've taken your Precious, and we've washed and washed your feet.'
#       `If you mean to come back to the Shire,' said Frodo, `you will find it hard to get a hold of Mr. Bilbo. I am far away.'
#      `But where shall we go?'asked Sam.
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --top_p 0.8 --prompt "The Shire was quiet."
# Out:
#  He was no longer troubled about his errand. He could go on walking quietly and quietly, wherever he liked to go, as long as he kept to the paths, and kept a few things in his pocket. He seemed to be getting along splendidly, and had become rather fond of the Company, even of Frodo. It seemed to him that it was wonderful to hear him talk in his own language, when there was no one else but them. He had come to the end of a long and curious journey, and he was grateful to have done so.
#      'I suppose you were just saying that you were glad to see me, Gandalf,' said Frodo; 'and glad to see you come back, and I could use the help of strangers, too, and that I might be making a few friends, if I wasn't looking after myself. But there are some funny people in the Shire, if you follow the signs. And you said I looked odd, I said I looked right. But that's a pity, because you look rather queer yourself.'
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --top_p 0.8 --prompt "Sauron was displeased."
# Out:
#  He was no longer interested in the Sword, but in the threat that it brought to his power. The Ring would only be used to keep the Council in check, not to reveal its true nature. If he felt that he was at need of the Ring he could leave it behind and use it. For the moment. as a matter of course, he was at Frodo's side, in his own business, not in his master's.
#      `Then, Master Galadriel,' he said, `if you will help me, I will deal with the Ring and all the other matters that I must. And if I am to aid you in your task, I must know the true purpose of your counsellors, and I must have the strength to do so.'
#       `Ah! you speak well,' said Gandalf. `I wish I could see them both together. But even so I will not trust to your guess alone. I shall have to search far and wide for a while, and I doubt very much what I can find. We must find the Ring first.'
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --top_p 0.8 --prompt "Three Rings for the Elven-kings under the sky,"
# Out:
# 06/03/2021 09:41:48 - INFO - __main__ -   Namespace(model_type='gpt2', model_name_or_path='output', prompt='Three Rings for the Elven-kings under the sky,', padding_text='', xlm_lang='', length=500, num_samples=1, temperature=1.0, repetition_penalty=1.0, top_k=0, top_p=0.8, no_cuda=False, seed=42, stop_token=None, device=device(type='cuda'), n_gpu=1)
#
# ...
#   7%|▋         | 33/500 [00:01<00:12, 35.94it/s]
#
#             Whence come these sheenless rings?
#            `Whence came these sheenless rings?'he murmured.
#      The light was dim and the shadows heavy; yet Gandalf now strode on, and the Moon passed from the sky. Slowly his eyes grew weary, and his voice went cold.
#      `This is no good. It will be useless, if we cannot find a way, now that we have seen the shapes and the fallen stones. If we cannot find a way, we must take the Great River. How do we get there?'he said.
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --top_p 0.8 --prompt "Gollum scowled angry"
# Out:
# , but no sign of fear or malice was seen on his face, except his great grey eyes.
#      `Do not be afraid!'said Frodo, speaking sternly. `We have done nothing wrong. You have done well, and very much. If only there were some way of doing it quicker. But this will do. Take your little fool to the Great River, if you can. But there is no water there. He will drown or die before he sees it.'
#      `But I have done my best,' said the orc. 'The job is done. It was only a trick, you understand. I do not want him on the bank, and he cannot swim. But the thing is not finished. I can make him swim, and he must swim. We cannot stay here, if we do not do something.'
#       `What can we do?'said Frodo. `We can swim, we can swim, or we can turn back. We can turn back, but it will be a long wait.'
#       `No, it is not,' said the orc. `But it may be our only hope. If we do not turn back, we shall get there and he will drown.'
#      `Maybe,' said Frodo. `But he can swim. He can swim!'
# ...

# %%
# !python data_processing\generation.py --model_type gpt2 --model_name_or_path output --length 500 --temperature 0.78 --repetition_penalty 1.2 --top_p 0.5 --prompt "Aragon looked at the cloaked figure."
# Out:
#  `He is a wizard,' he said, 'and a great lord of men.'
#      `A mighty king!' cried Legolas; and Gimli was amazed to see the old man in such a high place among the Riders: so tall and fair, yet so young and yet so old! He seemed like an older brother than the others that stood before him or followed after his lead into battle-field upon either side – but he had no helm nor sword. His face bore a keen and commanding look as if he were a judge of men's worth. And yet he spoke in a kindly voice with clear voices for the most part, and was not proud or angry. He smiled, though he did show signs also now more clearly then ever when he spoke softly to the others about their own affairs under sunlit sky."
#
# ...
